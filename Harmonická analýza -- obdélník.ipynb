# %% [markdown]
# Obdélníkový časový průběh s [DCL](https://cs.wikipedia.org/wiki/Střída_(elektronika)) 50% lze popsat vztahem:
#
# $$u_t() = \sum_{n=1}^\infty {4U_m \over \pi} { \cos(n\omega t - {\pi\over 2}) \over n }$$
#
# Vyzkoušejte si, kolik je třeba harmonických složek pro zachování tvaru tohoto časového průběhu.

# %%
t=linspace(0,2,500)

# %%
Um=1
f=1
m=4
u=zeros(len(t))
figure(figsize=(10,7))
minorticks_on()
xlabel(r'$\rightarrow$ \\t [s]',fontsize=16, x=0.9 )
ylabel(r'u [V] $\uparrow$',fontsize=16, y=0.9, rotation=0)
grid(True, 'major', linewidth=1)
grid(True, 'minor', linewidth=0.5)
for n in range(1,m+1)[::2]:
    harm = 4.*cos(n*2*pi*f*t-pi/2)/(pi*n)
    plot(t,harm,'--g')
    u = u + harm
#figure(figsize=(10,7))
plot(t,u,'r-',lw=2)
grid(1)

# %%
Um=1
f=1
m=10
u=zeros(len(t))
figure(figsize=(10,7))
minorticks_on()
xlabel(r'$\rightarrow$ \\t [s]',fontsize=16, x=0.9 )
ylabel(r'u [V] $\uparrow$',fontsize=16, y=0.9, rotation=0)
grid(True, 'major', linewidth=1)
grid(True, 'minor', linewidth=0.5)
for n in range(1,m+1)[::2]:
    harm = 4.*cos(n*2*pi*f*t-pi/2)/(pi*n)
    plot(t,harm,'--g')
    u = u + harm
#figure(figsize=(10,7))
plot(t,u,'r-',lw=2)
grid(1)

# %%
Um=1
f=1
m=50
u=zeros(len(t))
figure(figsize=(10,7))
minorticks_on()
xlabel(r'$\rightarrow$ \\t [s]',fontsize=16, x=0.9 )
ylabel(r'u [V] $\uparrow$',fontsize=16, y=0.9, rotation=0)
grid(True, 'major', linewidth=1)
grid(True, 'minor', linewidth=0.5)
for n in range(1,m+1)[::2]:
    harm = 4.*cos(n*2*pi*f*t-pi/2)/(pi*n)
    plot(t,harm,'--g')
    u = u + harm
#figure(figsize=(10,7))
plot(t,u,'r-',lw=2)
grid(1)

# %%
Um=1
f=1
m=100
u=zeros(len(t))
figure(figsize=(10,7))
minorticks_on()
xlabel(r'$\rightarrow$ \\t [s]',fontsize=16, x=0.9 )
ylabel(r'u [V] $\uparrow$',fontsize=16, y=0.9, rotation=0)
grid(True, 'major', linewidth=1)
grid(True, 'minor', linewidth=0.5)
for n in range(1,m+1)[::2]:
    harm = 4.*cos(n*2*pi*f*t-pi/2)/(pi*n)
    plot(t,harm,'--g')
    u = u + harm
#figure(figsize=(10,7))
plot(t,u,'r-',lw=2)
grid(1)

# %%
Um=1
f=1
m=1000
u=zeros(len(t))
figure(figsize=(10,7))
minorticks_on()
xlabel(r'$\rightarrow$ \\t [s]',fontsize=16, x=0.9 )
ylabel(r'u [V] $\uparrow$',fontsize=16, y=0.9, rotation=0)
grid(True, 'major', linewidth=1)
grid(True, 'minor', linewidth=0.5)
for n in range(1,m+1)[::2]:
    harm = 4.*cos(n*2*pi*f*t-pi/2)/(pi*n)
    plot(t,harm,'--g')
    u = u + harm
#figure(figsize=(10,7))
plot(t,u,'r-',lw=2)
grid(1)
