# %%
#%config InlineBackend.figure_format = 'svg'

# %%
plot(rand(30))
plot(rand(20))
grid()

# %% [markdown]
# * vytvořím proměnné
# $u_1=\sin(2\pi f t)$

# %%
t=linspace(0,1,100)
u=sin(2*pi*1*t)

# %% [markdown]
# * a nakreslím

# %%
plot(t,u)
grid(1)
